# %%
"""
  Ce programme permet de tracer la représentation graphique de
  vitesse en fonction du temps de chute du de la parachutiste.


  Modifier les listes t et v_y avec vos résultats expérimentaux.
  Cliquer sur Run.
"""


import matplotlib.pyplot as plt
fig = plt.figure()


### Fonction
def tracer_point(t, v):
    plt.plot(t, v, 'x', markersize=5)


def afficher_graphe():
    plt.xlabel("t (en s)")
    plt.ylabel("v (en m/s)")
    plt.title("Évolution de la vitesse au cours de la chute")
    plt.show()


#### Programme ######################################
# Valeurs expérimentales
t = [20, 10, 10, 10,        ]      # Remplacer par vos données expérimentales
v_y = [20, 10, 10, 10,        ]     # Remplacer par vos données expérimentales

#Vérification de la cohérence des listes
if len(v_y) != len(t):
    print("Les listes t et vy ne comportent pas le même nombre de données !")

# Calcul et tracer du graphique
for point in t:
    tracer_point(t, v_y)
afficher_graphe()
